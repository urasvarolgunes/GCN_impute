# %%
import torch
import torch.nn as nn
import pandas as pd

# %%
split = df[0].str.split(" ", n = 1, expand = True)
df["word"] = split[0]
df['embedding'] = split[1]
df = df.drop(0, axis = 1)

# %%
adj_mat = pd.read_csv("./LatentSemanticImputation/word_classification/matrices/affMat.csv", index_col=0).drop('y', axis = 1)
y = pd.read_csv("./LatentSemanticImputation/word_classification/matrices/affMat.csv", index_col=0)['y']
adj_mat_index = adj_mat.index.to_list()

# %%
glove_mat = pd.read_csv("./LatentSemanticImputation/word_classification/matrices/gloveMat.csv", index_col=0)
glove_mat_index = glove_mat.index.to_list()

# %%
train_mask = []
for i in range(len(adj_mat)):
    
    if adj_mat_index[i] in glove_mat_index:
        train_mask.append(i)

# %%
adj_mat.iloc[train_mask, :]
# Out:
#              REGN US EQUITY  UNM US EQUITY  UAL US EQUITY  OKE US EQUITY  \
# Facebook           0.174052       0.059304       0.119060       0.230242
# Varian             0.184139       0.137700       0.139299       0.207374
# Allergan           0.381017       0.210642       0.124967       0.187746
# Nucor              0.298215       0.398885       0.240242       0.336522
# Ventas             0.049587      -0.084660       0.025188       0.151018
# ...                     ...            ...            ...            ...
# Caterpillar        0.205736       0.435696       0.257313       0.397402
# Paychex            0.170059       0.273242       0.257718       0.178883
# Verizon            0.137301       0.219420       0.094678       0.229011
# CBS                0.136909       0.177134       0.162548       0.235502
# Micron             0.220560       0.165679       0.213872       0.162912
#
#              FB US EQUITY  KMI US EQUITY  SEE US EQUITY  TSN US EQUITY  \
# ...

# %%
glove_mat.drop(['300','301'], axis = 1)
# Out:
#                     0        1         2        3         4         5  \
# Facebook    -0.040208  0.45172 -0.293000  0.43092 -0.009503 -0.110830
# Varian       0.293450  0.22605  0.145180  0.58848  0.075919 -0.700200
# Allergan     0.683800  0.29279  0.065342  0.28826 -0.101740 -0.245000
# Nucor        0.317200  0.24979  0.644430 -0.86224 -0.658380 -0.149300
# Ventas       0.028289 -0.25496 -0.040969 -0.10904  0.792440  0.059963
# ...               ...      ...       ...      ...       ...       ...
# Caterpillar  0.351770  0.68704  0.060574 -0.55106  0.377650  0.726630
# Paychex     -0.336440 -0.14342  0.113880 -0.40520 -0.370650  0.547330
# Verizon      0.184220  0.80397 -0.022202 -0.46364  0.523490 -0.000045
# CBS         -0.078176  0.61518  0.013317 -0.20788 -0.215350 -0.072729
# Micron       0.012676  0.91376 -0.132040  0.52081 -0.136130  0.082593
#
#                     6         7         8         9  ...       290       291  \
# ...

# %%
glove_mat.shape
# Out:
# (206, 302)

# %%
np.sum(glove_mat.to_numpy(), 1)
# Out:
# array([8.62839528e+03, 3.35520971e+02, 3.70228589e+02, 9.61337608e+01,
#        5.21437687e+01, 1.09679194e+04, 8.08318856e+01, 2.64422898e+02,
#        1.83737476e+02, 1.71661393e+02, 2.07609446e+02, 5.22876925e+02,
#        3.55796577e+02, 3.38508134e+02, 2.04497356e+02, 3.86013535e+02,
#        7.51599113e+01, 8.81214679e+02, 9.79379356e+01, 1.10027770e+02,
#        1.47757913e+02, 5.91000218e+02, 3.12953561e+02, 3.05999989e+02,
#        1.27699493e+04, 2.13363441e+02, 3.53982132e+02, 1.40049899e+02,
#        4.85952781e+02, 1.98454685e+03, 7.97090320e+02, 1.83644460e+03,
#        6.05370708e+02, 3.63341304e+02, 1.01779467e+03, 2.44490361e+02,
#        1.52021637e+03, 2.17256448e+02, 6.53265172e+02, 1.37387690e+03,
#        1.46274678e+03, 1.39054093e+03, 1.80046220e+03, 1.65188836e+02,
#        2.48547616e+03, 1.40507446e+02, 5.80925638e+02, 4.17794085e+02,
#        5.61771925e+01, 1.31160755e+02, 1.26471131e+02, 1.56333340e+02,
# ...

# %%
adj_mat = pd.read_csv("./LatentSemanticImputation/word_classification/matrices/affMat.csv", index_col=0)
adj_mat
# Out:
#                     REGN US EQUITY  UNM US EQUITY  UAL US EQUITY  \
# Regeneron                 1.000000       0.151142       0.105208
# Unum_Group                0.151142       1.000000       0.283075
# United_Continental        0.105208       0.283075       1.000000
# ONEOK                     0.069935       0.149528       0.143929
# Facebook                  0.174052       0.059304       0.119060
# ...                            ...            ...            ...
# Verizon                   0.137301       0.219420       0.094678
# Union_Pacific             0.157936       0.421148       0.291897
# XL_Capital                0.084560       0.177677       0.094481
# CBS                       0.136909       0.177134       0.162548
# Micron                    0.220560       0.165679       0.213872
#
#                     OKE US EQUITY  FB US EQUITY  KMI US EQUITY  SEE US EQUITY  \
# Regeneron                0.069935      0.174052       0.230379       0.120237
# ...

# %%
pd.read_csv("./LatentSemanticImputation/word_classification/matrices/fullMat.csv", index_col=0)
# Out:
#                            0         1         2         3         4  \
# Regeneron           0.841414  1.512317  0.675493  2.357999  0.529899
# Unum_Group         -0.208115 -0.077768  1.278303  0.020541 -0.477928
# United_Continental  0.084431  0.236514  0.554012 -0.389547 -0.649251
# ONEOK              -1.027363 -0.455291  1.718671  0.162770  0.018373
# Facebook            0.038943  0.157847  0.177917 -0.115327 -0.410939
# ...                      ...       ...       ...       ...       ...
# Verizon            -0.398314 -0.230092  0.620022 -0.094381 -0.440382
# Union_Pacific       0.150045 -0.230192  0.813774 -0.054360  0.136712
# XL_Capital         -0.631991  0.116216 -0.098082 -0.146328 -1.157523
# CBS                -0.032082  0.009271  0.140478 -0.042760 -0.292019
# Micron             -0.702741 -0.785512 -0.144391 -0.056021 -2.280065
#
#                            5         6         7         8         9  ...  \
# ...

# %%
adj_mat = pd.read_csv("./LatentSemanticImputation/word_classification/matrices/affMat.csv", index_col=0).drop('y', axis = 1)

# %%
adj_mat
# Out:
#                     REGN US EQUITY  UNM US EQUITY  UAL US EQUITY  \
# Regeneron                 1.000000       0.151142       0.105208
# Unum_Group                0.151142       1.000000       0.283075
# United_Continental        0.105208       0.283075       1.000000
# ONEOK                     0.069935       0.149528       0.143929
# Facebook                  0.174052       0.059304       0.119060
# ...                            ...            ...            ...
# Verizon                   0.137301       0.219420       0.094678
# Union_Pacific             0.157936       0.421148       0.291897
# XL_Capital                0.084560       0.177677       0.094481
# CBS                       0.136909       0.177134       0.162548
# Micron                    0.220560       0.165679       0.213872
#
#                     OKE US EQUITY  FB US EQUITY  KMI US EQUITY  SEE US EQUITY  \
# Regeneron                0.069935      0.174052       0.230379       0.120237
# ...

# %%
def normalize_adj(adj):

    rowsum = np.sum(adj, 1)
    D_inv_sqrt = np.power(rowsum, -0.5).flatten()
    D_inv_sqrt[np.isinf(D_inv_sqrt)] = 0.
    D_mat_inv_sqrt = np.diag(D_inv_sqrt)
    return D_mat_inv_sqrt.dot(adj).dot(D_mat_inv_sqrt)

# %%
adj = np.array([[1,0.5,0.2],[0.3, 1, 0.5],[0.5,0.4, 1]])

# %%
normalize_adj(adj)
# Out:
# array([[0.58823529, 0.28583098, 0.11128298],
#        [0.17149859, 0.55555556, 0.27036904],
#        [0.27820744, 0.21629523, 0.52631579]])

# %%
adj
# Out:
# array([[1. , 0.5, 0.2],
#        [0.3, 1. , 0.5],
#        [0.5, 0.4, 1. ]])

# %%
(np.sqrt(1.7)*np.sqrt(1.8))
# Out:
# 0.5716619504750294

# %%
rowsum = np.sum(adj, 1)
print(rowsum)
D_inv_sqrt = np.power(rowsum, -0.5).flatten()
print(D_inv_sqrt)
D_inv_sqrt[np.isinf(D_inv_sqrt)] = 0.
print(D_inv_sqrt)
D_mat_inv_sqrt = np.diag(D_inv_sqrt)
print(D_mat_inv_sqrt)
D_mat_inv_sqrt.dot(adj).dot(D_mat_inv_sqrt)
# Out:
# [1.7 1.8 1.9]
# [0.76696499 0.74535599 0.72547625]
# [0.76696499 0.74535599 0.72547625]
# [[0.76696499 0.         0.        ]
#  [0.         0.74535599 0.        ]
#  [0.         0.         0.72547625]]
# array([[0.58823529, 0.28583098, 0.11128298],
#        [0.17149859, 0.55555556, 0.27036904],
#        [0.27820744, 0.21629523, 0.52631579]])

# %%
D_mat_inv_sqrt.dot(adj).dot(D_mat_inv_sqrt)
# Out:
# array([[0.58823529, 0.28583098, 0.11128298],
#        [0.17149859, 0.55555556, 0.27036904],
#        [0.27820744, 0.21629523, 0.52631579]])

# %%
(1)/(np.sqrt(1.7)*np.sqrt(1.7))
# Out:
# 0.5882352941176471

# %%
1/(np.sqrt(1.8)*np.sqrt(1.7))
# Out:
# 0.5716619504750294

# %%
adj
# Out:
# array([[1. , 0.5, 0.2],
#        [0.3, 1. , 0.5],
#        [0.5, 0.4, 1. ]])
